# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction" data-toc-modified-id="Introduction-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introduction</a></span></li><li><span><a href="#dis-module-in-python" data-toc-modified-id="dis-module-in-python-2"><span class="toc-item-num">2&nbsp;&nbsp;</span><code>dis</code> module in python</a></span></li><li><span><a href="#Basics" data-toc-modified-id="Basics-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Basics</a></span><ul class="toc-item"><li><span><a href="#Feeding-a-module" data-toc-modified-id="Feeding-a-module-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Feeding a module</a></span></li><li><span><a href="#Feeding-a-function" data-toc-modified-id="Feeding-a-function-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Feeding a function</a></span></li><li><span><a href="#Feeding-a-class" data-toc-modified-id="Feeding-a-class-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Feeding a class</a></span></li></ul></li><li><span><a href="#References" data-toc-modified-id="References-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>References</a></span></li></ul></div>

# %% [markdown]
# # Introduction
# <hr style = "border:2px solid black" ></hr>

# %% [markdown]
# <div class="alert alert-warning">
# <font color=black>
#
# **What?** Disassembling python bytecode
#
# </font>
# </div>

# %% [markdown]
# # `dis` module in python
# <hr style = "border:2px solid black" ></hr>

# %% [markdown]
# <div class="alert alert-info">
# <font color=black>
#
# - In Python, the dis module allows disassembly of Python code into the individual instructions executed by the Python interpreter (usually cPython as this is the most popular implementation) for each line.
#
# - This is useful for analysing and fine-tuning your code.
#
# </font>
# </div>

# %%
dir(dis)
# Out:
# ['Bytecode',
#  'COMPILER_FLAG_NAMES',
#  'EXTENDED_ARG',
#  'FORMAT_VALUE',
#  'FORMAT_VALUE_CONVERTERS',
#  'HAVE_ARGUMENT',
#  'Instruction',
#  'MAKE_FUNCTION',
#  'MAKE_FUNCTION_FLAGS',
#  '_Instruction',
#  '_OPARG_WIDTH',
#  '_OPNAME_WIDTH',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_disassemble_bytes',
#  '_disassemble_recursive',
#  '_disassemble_str',
#  '_format_code_info',
#  '_get_code_object',
#  '_get_const_info',
#  '_get_instructions_bytes',
#  '_get_name_info',
#  '_have_code',
#  '_test',
#  '_try_compile',
#  '_unpack_opargs',
#  'cmp_op',
#  'code_info',
#  'collections',
#  'dis',
#  'disassemble',
#  'disco',
#  'distb',
#  'findlabels',
#  'findlinestarts',
#  'get_instructions',
#  'hascompare',
#  'hasconst',
#  'hasfree',
#  'hasjabs',
#  'hasjrel',
#  'haslocal',
#  'hasname',
#  'hasnargs',
#  'io',
#  'opmap',
#  'opname',
#  'pretty_flags',
#  'show_code',
#  'stack_effect',
#  'sys',
#  'types']

# %% [markdown]
# # Basics
# <hr style = "border:2px solid black" ></hr>

# %% [markdown]
# <div class="alert alert-info">
# <font color=black>
#
# - The main method will use is `dis.dis`.
# - It takes either a function, method, class, module, code string, generator or byte sequence of raw bytecode and prints the disassembly of that code object to stdout.
# - In the case of a class, it will disassemble each method (also static and class methods).
# - For a module, it disassembles all functions in that module.
# - The columns returned are the following:
#     - The original line of code the disassembly is referencing.
#     - The address of the bytecode instruction.
#     - The name of the instruction.
#     - The index of the argument in the code block’s name and constant table.
#     - The human-friendly mapping from the argument index (4) to the actual value or name being referenced
#
# </font>
# </div>

# %% [markdown]
# ## Feeding a module

# %%
import dis, numpy
dis.dis(numpy)
# Out:
# Disassembly of Bytecode:
# Disassembly of __init__:
# 488           0 LOAD_GLOBAL              0 (_get_code_object)
#               2 LOAD_FAST                1 (x)
#               4 CALL_FUNCTION            1
#               6 DUP_TOP
#               8 LOAD_FAST                0 (self)
#              10 STORE_ATTR               1 (codeobj)
#              12 STORE_FAST               4 (co)
#
# 489          14 LOAD_FAST                2 (first_line)
#              16 LOAD_CONST               0 (None)
#              18 IS_OP                    0
#              20 POP_JUMP_IF_FALSE       38
#
# 490          22 LOAD_FAST                4 (co)
#              24 LOAD_ATTR                2 (co_firstlineno)
#              26 LOAD_FAST                0 (self)
#              28 STORE_ATTR               3 (first_line)
#
# 491          30 LOAD_CONST               1 (0)
#              32 LOAD_FAST                0 (self)
#              34 STORE_ATTR               4 (_line_offset)
#              36 JUMP_FORWARD            18 (to 56)
#
# 493     >>   38 LOAD_FAST                2 (first_line)
#              40 LOAD_FAST                0 (self)
#              42 STORE_ATTR               3 (first_line)
#
# 494          44 LOAD_FAST                2 (first_line)
#              46 LOAD_FAST                4 (co)
#              48 LOAD_ATTR                2 (co_firstlineno)
#              50 BINARY_SUBTRACT
#              52 LOAD_FAST                0 (self)
#              54 STORE_ATTR               4 (_line_offset)
#
# 495     >>   56 LOAD_FAST                4 (co)
#              58 LOAD_ATTR                5 (co_cellvars)
#              60 LOAD_FAST                4 (co)
#              62 LOAD_ATTR                6 (co_freevars)
#              64 BINARY_ADD
#              66 LOAD_FAST                0 (self)
#              68 STORE_ATTR               7 (_cell_names)
#
# 496          70 LOAD_GLOBAL              8 (dict)
#              72 LOAD_GLOBAL              9 (findlinestarts)
#              74 LOAD_FAST                4 (co)
#              76 CALL_FUNCTION            1
#              78 CALL_FUNCTION            1
#              80 LOAD_FAST                0 (self)
#              82 STORE_ATTR              10 (_linestarts)
#
# 497          84 LOAD_FAST                1 (x)
#              86 LOAD_FAST                0 (self)
#              88 STORE_ATTR              11 (_original_object)
#
# 498          90 LOAD_FAST                3 (current_offset)
#              92 LOAD_FAST                0 (self)
#              94 STORE_ATTR              12 (current_offset)
#              96 LOAD_CONST               0 (None)
#              98 RETURN_VALUE
#
# Disassembly of __iter__:
# 501           0 LOAD_FAST                0 (self)
#               2 LOAD_ATTR                0 (codeobj)
#               4 STORE_FAST               1 (co)
#
# 502           6 LOAD_GLOBAL              1 (_get_instructions_bytes)
#               8 LOAD_FAST                1 (co)
#              10 LOAD_ATTR                2 (co_code)
#              12 LOAD_FAST                1 (co)
#              14 LOAD_ATTR                3 (co_varnames)
#              16 LOAD_FAST                1 (co)
#              18 LOAD_ATTR                4 (co_names)
#
# 503          20 LOAD_FAST                1 (co)
#              22 LOAD_ATTR                5 (co_consts)
#              24 LOAD_FAST                0 (self)
#              26 LOAD_ATTR                6 (_cell_names)
#
# 504          28 LOAD_FAST                0 (self)
#              30 LOAD_ATTR                7 (_linestarts)
#
# 505          32 LOAD_FAST                0 (self)
#              34 LOAD_ATTR                8 (_line_offset)
#
# 502          36 LOAD_CONST               1 (('line_offset',))
#              38 CALL_FUNCTION_KW         7
#              40 RETURN_VALUE
#
# Disassembly of __repr__:
# 508           0 LOAD_CONST               1 ('{}({!r})')
#               2 LOAD_METHOD              0 (format)
#               4 LOAD_FAST                0 (self)
#               6 LOAD_ATTR                1 (__class__)
#               8 LOAD_ATTR                2 (__name__)
#
# 509          10 LOAD_FAST                0 (self)
#              12 LOAD_ATTR                3 (_original_object)
#
# 508          14 CALL_METHOD              2
#              16 RETURN_VALUE
#
# Disassembly of dis:
# 524           0 LOAD_FAST                0 (self)
#               2 LOAD_ATTR                0 (codeobj)
#               4 STORE_FAST               1 (co)
#
# 525           6 LOAD_FAST                0 (self)
#               8 LOAD_ATTR                1 (current_offset)
#              10 LOAD_CONST               1 (None)
#              12 IS_OP                    1
#              14 POP_JUMP_IF_FALSE       24
#
# 526          16 LOAD_FAST                0 (self)
#              18 LOAD_ATTR                1 (current_offset)
#              20 STORE_FAST               2 (offset)
#              22 JUMP_FORWARD             4 (to 28)
#
# 528     >>   24 LOAD_CONST               2 (-1)
#              26 STORE_FAST               2 (offset)
#
# 529     >>   28 LOAD_GLOBAL              2 (io)
#              30 LOAD_METHOD              3 (StringIO)
#              32 CALL_METHOD              0
#              34 SETUP_WITH              64 (to 100)
#              36 STORE_FAST               3 (output)
#
# 530          38 LOAD_GLOBAL              4 (_disassemble_bytes)
#              40 LOAD_FAST                1 (co)
#              42 LOAD_ATTR                5 (co_code)
#              44 LOAD_FAST                1 (co)
#              46 LOAD_ATTR                6 (co_varnames)
#
# 531          48 LOAD_FAST                1 (co)
#              50 LOAD_ATTR                7 (co_names)
#              52 LOAD_FAST                1 (co)
#              54 LOAD_ATTR                8 (co_consts)
#
# 532          56 LOAD_FAST                0 (self)
#              58 LOAD_ATTR                9 (_cell_names)
#
# 533          60 LOAD_FAST                0 (self)
#              62 LOAD_ATTR               10 (_linestarts)
#
# 534          64 LOAD_FAST                0 (self)
#              66 LOAD_ATTR               11 (_line_offset)
#
# 535          68 LOAD_FAST                3 (output)
#
# 536          70 LOAD_FAST                2 (offset)
#
# 530          72 LOAD_CONST               3 (('varnames', 'names', 'constants', 'cells', 'linestarts', 'line_offset', 'file', 'lasti'))
#              74 CALL_FUNCTION_KW         9
#              76 POP_TOP
#
# 537          78 LOAD_FAST                3 (output)
#              80 LOAD_METHOD             12 (getvalue)
#              82 CALL_METHOD              0
#              84 POP_BLOCK
#              86 ROT_TWO
#              88 LOAD_CONST               1 (None)
#              90 DUP_TOP
#              92 DUP_TOP
#              94 CALL_FUNCTION            3
#              96 POP_TOP
#              98 RETURN_VALUE
#         >>  100 WITH_EXCEPT_START
#             102 POP_JUMP_IF_TRUE       106
#             104 RERAISE
#         >>  106 POP_TOP
#             108 POP_TOP
#             110 POP_TOP
#             112 POP_EXCEPT
#             114 POP_TOP
#             116 LOAD_CONST               1 (None)
#             118 RETURN_VALUE
#
# Disassembly of from_traceback:
# 514     >>    0 LOAD_FAST                1 (tb)
#               2 LOAD_ATTR                0 (tb_next)
#               4 POP_JUMP_IF_FALSE       14
#
# 515           6 LOAD_FAST                1 (tb)
#               8 LOAD_ATTR                0 (tb_next)
#              10 STORE_FAST               1 (tb)
#              12 JUMP_ABSOLUTE            0
#
# 516     >>   14 LOAD_FAST                0 (cls)
#              16 LOAD_FAST                1 (tb)
#              18 LOAD_ATTR                1 (tb_frame)
#              20 LOAD_ATTR                2 (f_code)
#              22 LOAD_FAST                1 (tb)
#              24 LOAD_ATTR                3 (tb_lasti)
#              26 LOAD_CONST               1 (('current_offset',))
#              28 CALL_FUNCTION_KW         2
#              30 RETURN_VALUE
#
# Disassembly of info:
# 520           0 LOAD_GLOBAL              0 (_format_code_info)
#               2 LOAD_FAST                0 (self)
#               4 LOAD_ATTR                1 (codeobj)
#               6 CALL_FUNCTION            1
#               8 RETURN_VALUE
#
#
# Disassembly of Instruction:
# Disassembly of _disassemble:
# 230           0 BUILD_LIST               0
#               2 STORE_FAST               4 (fields)
#
# 232           4 LOAD_FAST                1 (lineno_width)
#               6 POP_JUMP_IF_FALSE       58
#
# 233           8 LOAD_FAST                0 (self)
#              10 LOAD_ATTR                0 (starts_line)
#              12 LOAD_CONST               1 (None)
#              14 IS_OP                    1
#              16 POP_JUMP_IF_FALSE       44
#
# 234          18 LOAD_CONST               2 ('%%%dd')
#              20 LOAD_FAST                1 (lineno_width)
#              22 BINARY_MODULO
#              24 STORE_FAST               5 (lineno_fmt)
#
# 235          26 LOAD_FAST                4 (fields)
#              28 LOAD_METHOD              1 (append)
#              30 LOAD_FAST                5 (lineno_fmt)
#              32 LOAD_FAST                0 (self)
#              34 LOAD_ATTR                0 (starts_line)
#              36 BINARY_MODULO
#              38 CALL_METHOD              1
#              40 POP_TOP
#              42 JUMP_FORWARD            14 (to 58)
#
# 237     >>   44 LOAD_FAST                4 (fields)
#              46 LOAD_METHOD              1 (append)
#              48 LOAD_CONST               3 (' ')
#              50 LOAD_FAST                1 (lineno_width)
#              52 BINARY_MULTIPLY
#              54 CALL_METHOD              1
#              56 POP_TOP
#
# 239     >>   58 LOAD_FAST                2 (mark_as_current)
#              60 POP_JUMP_IF_FALSE       74
#
# 240          62 LOAD_FAST                4 (fields)
#              64 LOAD_METHOD              1 (append)
#              66 LOAD_CONST               4 ('-->')
#              68 CALL_METHOD              1
#              70 POP_TOP
#              72 JUMP_FORWARD            10 (to 84)
#
# 242     >>   74 LOAD_FAST                4 (fields)
#              76 LOAD_METHOD              1 (append)
#              78 LOAD_CONST               5 ('   ')
#              80 CALL_METHOD              1
#              82 POP_TOP
#
# 244     >>   84 LOAD_FAST                0 (self)
#              86 LOAD_ATTR                2 (is_jump_target)
#              88 POP_JUMP_IF_FALSE      102
#
# 245          90 LOAD_FAST                4 (fields)
#              92 LOAD_METHOD              1 (append)
#              94 LOAD_CONST               6 ('>>')
#              96 CALL_METHOD              1
#              98 POP_TOP
#             100 JUMP_FORWARD            10 (to 112)
#
# 247     >>  102 LOAD_FAST                4 (fields)
#             104 LOAD_METHOD              1 (append)
#             106 LOAD_CONST               7 ('  ')
#             108 CALL_METHOD              1
#             110 POP_TOP
#
# 249     >>  112 LOAD_FAST                4 (fields)
#             114 LOAD_METHOD              1 (append)
#             116 LOAD_GLOBAL              3 (repr)
#             118 LOAD_FAST                0 (self)
#             120 LOAD_ATTR                4 (offset)
#             122 CALL_FUNCTION            1
#             124 LOAD_METHOD              5 (rjust)
#             126 LOAD_FAST                3 (offset_width)
#             128 CALL_METHOD              1
#             130 CALL_METHOD              1
#             132 POP_TOP
#
# 251         134 LOAD_FAST                4 (fields)
#             136 LOAD_METHOD              1 (append)
#             138 LOAD_FAST                0 (self)
#             140 LOAD_ATTR                6 (opname)
#             142 LOAD_METHOD              7 (ljust)
#             144 LOAD_GLOBAL              8 (_OPNAME_WIDTH)
#             146 CALL_METHOD              1
#             148 CALL_METHOD              1
#             150 POP_TOP
#
# 253         152 LOAD_FAST                0 (self)
#             154 LOAD_ATTR                9 (arg)
#             156 LOAD_CONST               1 (None)
#             158 IS_OP                    1
#             160 POP_JUMP_IF_FALSE      210
#
# 254         162 LOAD_FAST                4 (fields)
#             164 LOAD_METHOD              1 (append)
#             166 LOAD_GLOBAL              3 (repr)
#             168 LOAD_FAST                0 (self)
#             170 LOAD_ATTR                9 (arg)
#             172 CALL_FUNCTION            1
#             174 LOAD_METHOD              5 (rjust)
#             176 LOAD_GLOBAL             10 (_OPARG_WIDTH)
#             178 CALL_METHOD              1
#             180 CALL_METHOD              1
#             182 POP_TOP
#
# 256         184 LOAD_FAST                0 (self)
#             186 LOAD_ATTR               11 (argrepr)
#             188 POP_JUMP_IF_FALSE      210
#
# 257         190 LOAD_FAST                4 (fields)
#             192 LOAD_METHOD              1 (append)
#             194 LOAD_CONST               8 ('(')
#             196 LOAD_FAST                0 (self)
#             198 LOAD_ATTR               11 (argrepr)
#             200 BINARY_ADD
#             202 LOAD_CONST               9 (')')
#             204 BINARY_ADD
#             206 CALL_METHOD              1
#             208 POP_TOP
#
# 258     >>  210 LOAD_CONST               3 (' ')
#             212 LOAD_METHOD             12 (join)
#             214 LOAD_FAST                4 (fields)
#             216 CALL_METHOD              1
#             218 LOAD_METHOD             13 (rstrip)
#             220 CALL_METHOD              0
#             222 RETURN_VALUE
#
#
# Disassembly of _Instruction:
# Disassembly of __getnewargs__:
# 466           0 LOAD_DEREF               0 (_tuple)
#               2 LOAD_FAST                0 (self)
#               4 CALL_FUNCTION            1
#               6 RETURN_VALUE
#
# Disassembly of __new__:
#   1           0 LOAD_GLOBAL              0 (_tuple_new)
#               2 LOAD_FAST                0 (_cls)
#               4 LOAD_FAST                1 (opname)
#               6 LOAD_FAST                2 (opcode)
#               8 LOAD_FAST                3 (arg)
#              10 LOAD_FAST                4 (argval)
#              12 LOAD_FAST                5 (argrepr)
#              14 LOAD_FAST                6 (offset)
#              16 LOAD_FAST                7 (starts_line)
#              18 LOAD_FAST                8 (is_jump_target)
#              20 BUILD_TUPLE              8
#              22 CALL_FUNCTION            2
#              24 RETURN_VALUE
#
# Disassembly of __repr__:
# 458           0 LOAD_FAST                0 (self)
#               2 LOAD_ATTR                0 (__class__)
#               4 LOAD_ATTR                1 (__name__)
#               6 LOAD_DEREF               0 (repr_fmt)
#               8 LOAD_FAST                0 (self)
#              10 BINARY_MODULO
#              12 BINARY_ADD
#              14 RETURN_VALUE
#
# Disassembly of _asdict:
# 462           0 LOAD_DEREF               0 (_dict)
#               2 LOAD_DEREF               1 (_zip)
#               4 LOAD_FAST                0 (self)
#               6 LOAD_ATTR                0 (_fields)
#               8 LOAD_FAST                0 (self)
#              10 CALL_FUNCTION            2
#              12 CALL_FUNCTION            1
#              14 RETURN_VALUE
#
# Disassembly of _make:
# 439           0 LOAD_DEREF               2 (tuple_new)
#               2 LOAD_FAST                0 (cls)
#               4 LOAD_FAST                1 (iterable)
#               6 CALL_FUNCTION            2
#               8 STORE_FAST               2 (result)
#
# 440          10 LOAD_DEREF               0 (_len)
#              12 LOAD_FAST                2 (result)
#              14 CALL_FUNCTION            1
#              16 LOAD_DEREF               1 (num_fields)
#              18 COMPARE_OP               3 (!=)
#              20 POP_JUMP_IF_FALSE       46
#
# 441          22 LOAD_GLOBAL              0 (TypeError)
#              24 LOAD_CONST               1 ('Expected ')
#              26 LOAD_DEREF               1 (num_fields)
#              28 FORMAT_VALUE             0
#              30 LOAD_CONST               2 (' arguments, got ')
#              32 LOAD_GLOBAL              1 (len)
#              34 LOAD_FAST                2 (result)
#              36 CALL_FUNCTION            1
#              38 FORMAT_VALUE             0
#              40 BUILD_STRING             4
#              42 CALL_FUNCTION            1
#              44 RAISE_VARARGS            1
#
# 442     >>   46 LOAD_FAST                2 (result)
#              48 RETURN_VALUE
#
# Disassembly of _replace:
# 448           0 LOAD_FAST                0 (self)
#               2 LOAD_METHOD              0 (_make)
#               4 LOAD_DEREF               0 (_map)
#               6 LOAD_FAST                1 (kwds)
#               8 LOAD_ATTR                1 (pop)
#              10 LOAD_DEREF               1 (field_names)
#              12 LOAD_FAST                0 (self)
#              14 CALL_FUNCTION            3
#              16 CALL_METHOD              1
#              18 STORE_FAST               2 (result)
#
# 449          20 LOAD_FAST                1 (kwds)
#              22 POP_JUMP_IF_FALSE       42
#
# 450          24 LOAD_GLOBAL              2 (ValueError)
#              26 LOAD_CONST               1 ('Got unexpected field names: ')
#              28 LOAD_GLOBAL              3 (list)
#              30 LOAD_FAST                1 (kwds)
#              32 CALL_FUNCTION            1
#              34 FORMAT_VALUE             2 (repr)
#              36 BUILD_STRING             2
#              38 CALL_FUNCTION            1
#              40 RAISE_VARARGS            1
#
# 451     >>   42 LOAD_FAST                2 (result)
#              44 RETURN_VALUE
#
#
# Disassembly of _disassemble_bytes:
# 387           0 LOAD_FAST                6 (linestarts)
#               2 LOAD_CONST               0 (None)
#               4 IS_OP                    1
#               6 STORE_FAST               9 (show_lineno)
#
# 388           8 LOAD_FAST                9 (show_lineno)
#              10 POP_JUMP_IF_FALSE       56
#
# 389          12 LOAD_GLOBAL              0 (max)
#              14 LOAD_FAST                6 (linestarts)
#              16 LOAD_METHOD              1 (values)
#              18 CALL_METHOD              0
#              20 CALL_FUNCTION            1
#              22 LOAD_FAST                8 (line_offset)
#              24 BINARY_ADD
#              26 STORE_FAST              10 (maxlineno)
#
# 390          28 LOAD_FAST               10 (maxlineno)
#              30 LOAD_CONST               1 (1000)
#              32 COMPARE_OP               5 (>=)
#              34 POP_JUMP_IF_FALSE       50
#
# 391          36 LOAD_GLOBAL              2 (len)
#              38 LOAD_GLOBAL              3 (str)
#              40 LOAD_FAST               10 (maxlineno)
#              42 CALL_FUNCTION            1
#              44 CALL_FUNCTION            1
#              46 STORE_FAST              11 (lineno_width)
#              48 JUMP_ABSOLUTE           60
#
# 393     >>   50 LOAD_CONST               2 (3)
#              52 STORE_FAST              11 (lineno_width)
#              54 JUMP_FORWARD             4 (to 60)
#
# 395     >>   56 LOAD_CONST               3 (0)
#              58 STORE_FAST              11 (lineno_width)
#
# 396     >>   60 LOAD_GLOBAL              2 (len)
#              62 LOAD_FAST                0 (code)
#              64 CALL_FUNCTION            1
#              66 LOAD_CONST               4 (2)
#              68 BINARY_SUBTRACT
#              70 STORE_FAST              12 (maxoffset)
#
# 397          72 LOAD_FAST               12 (maxoffset)
#              74 LOAD_CONST               5 (10000)
#              76 COMPARE_OP               5 (>=)
#              78 POP_JUMP_IF_FALSE       94
#
# 398          80 LOAD_GLOBAL              2 (len)
#              82 LOAD_GLOBAL              3 (str)
#              84 LOAD_FAST               12 (maxoffset)
#              86 CALL_FUNCTION            1
#              88 CALL_FUNCTION            1
#              90 STORE_FAST              13 (offset_width)
#              92 JUMP_FORWARD             4 (to 98)
#
# 400     >>   94 LOAD_CONST               6 (4)
#              96 STORE_FAST              13 (offset_width)
#
# 401     >>   98 LOAD_GLOBAL              4 (_get_instructions_bytes)
#             100 LOAD_FAST                0 (code)
#             102 LOAD_FAST                2 (varnames)
#             104 LOAD_FAST                3 (names)
#
# 402         106 LOAD_FAST                4 (constants)
#             108 LOAD_FAST                5 (cells)
#             110 LOAD_FAST                6 (linestarts)
#
# 403         112 LOAD_FAST                8 (line_offset)
#
# 401         114 LOAD_CONST               7 (('line_offset',))
#             116 CALL_FUNCTION_KW         7
#             118 GET_ITER
#         >>  120 FOR_ITER                74 (to 196)
#             122 STORE_FAST              14 (instr)
#
# 404         124 LOAD_FAST                9 (show_lineno)
#             126 JUMP_IF_FALSE_OR_POP   146
#
# 405         128 LOAD_FAST               14 (instr)
#             130 LOAD_ATTR                5 (starts_line)
#             132 LOAD_CONST               0 (None)
#             134 IS_OP                    1
#
# 404         136 JUMP_IF_FALSE_OR_POP   146
#
# 406         138 LOAD_FAST               14 (instr)
#             140 LOAD_ATTR                6 (offset)
#             142 LOAD_CONST               3 (0)
#             144 COMPARE_OP               4 (>)
#
# 404     >>  146 STORE_FAST              15 (new_source_line)
#
# 407         148 LOAD_FAST               15 (new_source_line)
#             150 POP_JUMP_IF_FALSE      162
#
# 408         152 LOAD_GLOBAL              7 (print)
#             154 LOAD_FAST                7 (file)
#             156 LOAD_CONST               8 (('file',))
#             158 CALL_FUNCTION_KW         1
#             160 POP_TOP
#
# 409     >>  162 LOAD_FAST               14 (instr)
#             164 LOAD_ATTR                6 (offset)
#             166 LOAD_FAST                1 (lasti)
#             168 COMPARE_OP               2 (==)
#             170 STORE_FAST              16 (is_current_instr)
#
# 410         172 LOAD_GLOBAL              7 (print)
#             174 LOAD_FAST               14 (instr)
#             176 LOAD_METHOD              8 (_disassemble)
#             178 LOAD_FAST               11 (lineno_width)
#             180 LOAD_FAST               16 (is_current_instr)
#             182 LOAD_FAST               13 (offset_width)
#             184 CALL_METHOD              3
#
# 411         186 LOAD_FAST                7 (file)
#
# 410         188 LOAD_CONST               8 (('file',))
#             190 CALL_FUNCTION_KW         2
#             192 POP_TOP
#             194 JUMP_ABSOLUTE          120
#         >>  196 LOAD_CONST               0 (None)
#             198 RETURN_VALUE
#
# Disassembly of _disassemble_recursive:
# 373           0 LOAD_GLOBAL              0 (disassemble)
#               2 LOAD_FAST                0 (co)
#               4 LOAD_FAST                1 (file)
#               6 LOAD_CONST               1 (('file',))
#               8 CALL_FUNCTION_KW         2
#              10 POP_TOP
#
# 374          12 LOAD_FAST                2 (depth)
#              14 LOAD_CONST               0 (None)
#              16 IS_OP                    0
#              18 POP_JUMP_IF_TRUE        28
#              20 LOAD_FAST                2 (depth)
#              22 LOAD_CONST               2 (0)
#              24 COMPARE_OP               4 (>)
#              26 POP_JUMP_IF_FALSE      108
#
# 375     >>   28 LOAD_FAST                2 (depth)
#              30 LOAD_CONST               0 (None)
#              32 IS_OP                    1
#              34 POP_JUMP_IF_FALSE       44
#
# 376          36 LOAD_FAST                2 (depth)
#              38 LOAD_CONST               3 (1)
#              40 BINARY_SUBTRACT
#              42 STORE_FAST               2 (depth)
#
# 377     >>   44 LOAD_FAST                0 (co)
#              46 LOAD_ATTR                1 (co_consts)
#              48 GET_ITER
#         >>   50 FOR_ITER                56 (to 108)
#              52 STORE_FAST               3 (x)
#
# 378          54 LOAD_GLOBAL              2 (hasattr)
#              56 LOAD_FAST                3 (x)
#              58 LOAD_CONST               4 ('co_code')
#              60 CALL_FUNCTION            2
#              62 POP_JUMP_IF_FALSE       50
#
# 379          64 LOAD_GLOBAL              3 (print)
#              66 LOAD_FAST                1 (file)
#              68 LOAD_CONST               1 (('file',))
#              70 CALL_FUNCTION_KW         1
#              72 POP_TOP
#
# 380          74 LOAD_GLOBAL              3 (print)
#              76 LOAD_CONST               5 ('Disassembly of %r:')
#              78 LOAD_FAST                3 (x)
#              80 BUILD_TUPLE              1
#              82 BINARY_MODULO
#              84 LOAD_FAST                1 (file)
#              86 LOAD_CONST               1 (('file',))
#              88 CALL_FUNCTION_KW         2
#              90 POP_TOP
#
# 381          92 LOAD_GLOBAL              4 (_disassemble_recursive)
#              94 LOAD_FAST                3 (x)
#              96 LOAD_FAST                1 (file)
#              98 LOAD_FAST                2 (depth)
#             100 LOAD_CONST               6 (('file', 'depth'))
#             102 CALL_FUNCTION_KW         3
#             104 POP_TOP
#             106 JUMP_ABSOLUTE           50
#         >>  108 LOAD_CONST               0 (None)
#             110 RETURN_VALUE
#
# Disassembly of _disassemble_str:
# 415           0 LOAD_GLOBAL              0 (_disassemble_recursive)
#               2 LOAD_GLOBAL              1 (_try_compile)
#               4 LOAD_FAST                0 (source)
#               6 LOAD_CONST               1 ('<dis>')
#               8 CALL_FUNCTION            2
#              10 BUILD_TUPLE              1
#              12 BUILD_MAP                0
#              14 LOAD_FAST                1 (kwargs)
#              16 DICT_MERGE               1
#              18 CALL_FUNCTION_EX         1
#              20 POP_TOP
#              22 LOAD_CONST               2 (None)
#              24 RETURN_VALUE
#
# Disassembly of _format_code_info:
# 156           0 BUILD_LIST               0
#               2 STORE_FAST               1 (lines)
#
# 157           4 LOAD_FAST                1 (lines)
#               6 LOAD_METHOD              0 (append)
#               8 LOAD_CONST               1 ('Name:              %s')
#              10 LOAD_FAST                0 (co)
#              12 LOAD_ATTR                1 (co_name)
#              14 BINARY_MODULO
#              16 CALL_METHOD              1
#              18 POP_TOP
#
# 158          20 LOAD_FAST                1 (lines)
#              22 LOAD_METHOD              0 (append)
#              24 LOAD_CONST               2 ('Filename:          %s')
#              26 LOAD_FAST                0 (co)
#              28 LOAD_ATTR                2 (co_filename)
#              30 BINARY_MODULO
#              32 CALL_METHOD              1
#              34 POP_TOP
#
# 159          36 LOAD_FAST                1 (lines)
#              38 LOAD_METHOD              0 (append)
#              40 LOAD_CONST               3 ('Argument count:    %s')
#              42 LOAD_FAST                0 (co)
#              44 LOAD_ATTR                3 (co_argcount)
#              46 BINARY_MODULO
#              48 CALL_METHOD              1
#              50 POP_TOP
#
# 160          52 LOAD_FAST                1 (lines)
#              54 LOAD_METHOD              0 (append)
#              56 LOAD_CONST               4 ('Positional-only arguments: %s')
#              58 LOAD_FAST                0 (co)
#              60 LOAD_ATTR                4 (co_posonlyargcount)
#              62 BINARY_MODULO
#              64 CALL_METHOD              1
#              66 POP_TOP
#
# 161          68 LOAD_FAST                1 (lines)
#              70 LOAD_METHOD              0 (append)
#              72 LOAD_CONST               5 ('Kw-only arguments: %s')
#              74 LOAD_FAST                0 (co)
#              76 LOAD_ATTR                5 (co_kwonlyargcount)
#              78 BINARY_MODULO
#              80 CALL_METHOD              1
#              82 POP_TOP
#
# 162          84 LOAD_FAST                1 (lines)
#              86 LOAD_METHOD              0 (append)
#              88 LOAD_CONST               6 ('Number of locals:  %s')
#              90 LOAD_FAST                0 (co)
#              92 LOAD_ATTR                6 (co_nlocals)
#              94 BINARY_MODULO
#              96 CALL_METHOD              1
#              98 POP_TOP
#
# 163         100 LOAD_FAST                1 (lines)
#             102 LOAD_METHOD              0 (append)
#             104 LOAD_CONST               7 ('Stack size:        %s')
#             106 LOAD_FAST                0 (co)
#             108 LOAD_ATTR                7 (co_stacksize)
#             110 BINARY_MODULO
#             112 CALL_METHOD              1
#             114 POP_TOP
#
# 164         116 LOAD_FAST                1 (lines)
#             118 LOAD_METHOD              0 (append)
#             120 LOAD_CONST               8 ('Flags:             %s')
#             122 LOAD_GLOBAL              8 (pretty_flags)
#             124 LOAD_FAST                0 (co)
#             126 LOAD_ATTR                9 (co_flags)
#             128 CALL_FUNCTION            1
#             130 BINARY_MODULO
#             132 CALL_METHOD              1
#             134 POP_TOP
#
# 165         136 LOAD_FAST                0 (co)
#             138 LOAD_ATTR               10 (co_consts)
#             140 POP_JUMP_IF_FALSE      182
#
# 166         142 LOAD_FAST                1 (lines)
#             144 LOAD_METHOD              0 (append)
#             146 LOAD_CONST               9 ('Constants:')
#             148 CALL_METHOD              1
#             150 POP_TOP
#
# 167         152 LOAD_GLOBAL             11 (enumerate)
#             154 LOAD_FAST                0 (co)
#             156 LOAD_ATTR               10 (co_consts)
#             158 CALL_FUNCTION            1
#             160 GET_ITER
#         >>  162 FOR_ITER                18 (to 182)
#             164 STORE_FAST               2 (i_c)
#
# 168         166 LOAD_FAST                1 (lines)
#             168 LOAD_METHOD              0 (append)
#             170 LOAD_CONST              10 ('%4d: %r')
#             172 LOAD_FAST                2 (i_c)
#             174 BINARY_MODULO
#             176 CALL_METHOD              1
#             178 POP_TOP
#             180 JUMP_ABSOLUTE          162
#
# 169     >>  182 LOAD_FAST                0 (co)
#             184 LOAD_ATTR               12 (co_names)
#             186 POP_JUMP_IF_FALSE      228
#
# 170         188 LOAD_FAST                1 (lines)
#             190 LOAD_METHOD              0 (append)
#             192 LOAD_CONST              11 ('Names:')
#             194 CALL_METHOD              1
#             196 POP_TOP
#
# 171         198 LOAD_GLOBAL             11 (enumerate)
#             200 LOAD_FAST                0 (co)
#             202 LOAD_ATTR               12 (co_names)
#             204 CALL_FUNCTION            1
#             206 GET_ITER
#         >>  208 FOR_ITER                18 (to 228)
#             210 STORE_FAST               3 (i_n)
#
# 172         212 LOAD_FAST                1 (lines)
#             214 LOAD_METHOD              0 (append)
#             216 LOAD_CONST              12 ('%4d: %s')
#             218 LOAD_FAST                3 (i_n)
#             220 BINARY_MODULO
#             222 CALL_METHOD              1
#             224 POP_TOP
#             226 JUMP_ABSOLUTE          208
#
# 173     >>  228 LOAD_FAST                0 (co)
#             230 LOAD_ATTR               13 (co_varnames)
#             232 EXTENDED_ARG             1
#             234 POP_JUMP_IF_FALSE      278
#
# 174         236 LOAD_FAST                1 (lines)
#             238 LOAD_METHOD              0 (append)
#             240 LOAD_CONST              13 ('Variable names:')
#             242 CALL_METHOD              1
#             244 POP_TOP
#
# 175         246 LOAD_GLOBAL             11 (enumerate)
#             248 LOAD_FAST                0 (co)
#             250 LOAD_ATTR               13 (co_varnames)
#             252 CALL_FUNCTION            1
#             254 GET_ITER
#         >>  256 FOR_ITER                20 (to 278)
#             258 STORE_FAST               3 (i_n)
#
# 176         260 LOAD_FAST                1 (lines)
#             262 LOAD_METHOD              0 (append)
#             264 LOAD_CONST              12 ('%4d: %s')
#             266 LOAD_FAST                3 (i_n)
#             268 BINARY_MODULO
#             270 CALL_METHOD              1
#             272 POP_TOP
#             274 EXTENDED_ARG             1
#             276 JUMP_ABSOLUTE          256
#
# 177     >>  278 LOAD_FAST                0 (co)
#             280 LOAD_ATTR               14 (co_freevars)
#             282 EXTENDED_ARG             1
#             284 POP_JUMP_IF_FALSE      328
#
# 178         286 LOAD_FAST                1 (lines)
#             288 LOAD_METHOD              0 (append)
#             290 LOAD_CONST              14 ('Free variables:')
#             292 CALL_METHOD              1
#             294 POP_TOP
#
# 179         296 LOAD_GLOBAL             11 (enumerate)
#             298 LOAD_FAST                0 (co)
#             300 LOAD_ATTR               14 (co_freevars)
#             302 CALL_FUNCTION            1
#             304 GET_ITER
#         >>  306 FOR_ITER                20 (to 328)
#             308 STORE_FAST               3 (i_n)
#
# 180         310 LOAD_FAST                1 (lines)
#             312 LOAD_METHOD              0 (append)
#             314 LOAD_CONST              12 ('%4d: %s')
#             316 LOAD_FAST                3 (i_n)
#             318 BINARY_MODULO
#             320 CALL_METHOD              1
#             322 POP_TOP
#             324 EXTENDED_ARG             1
#             326 JUMP_ABSOLUTE          306
#
# 181     >>  328 LOAD_FAST                0 (co)
#             330 LOAD_ATTR               15 (co_cellvars)
#             332 EXTENDED_ARG             1
#             334 POP_JUMP_IF_FALSE      378
#
# 182         336 LOAD_FAST                1 (lines)
#             338 LOAD_METHOD              0 (append)
#             340 LOAD_CONST              15 ('Cell variables:')
#             342 CALL_METHOD              1
#             344 POP_TOP
#
# 183         346 LOAD_GLOBAL             11 (enumerate)
#             348 LOAD_FAST                0 (co)
#             350 LOAD_ATTR               15 (co_cellvars)
#             352 CALL_FUNCTION            1
#             354 GET_ITER
#         >>  356 FOR_ITER                20 (to 378)
#             358 STORE_FAST               3 (i_n)
#
# 184         360 LOAD_FAST                1 (lines)
#             362 LOAD_METHOD              0 (append)
#             364 LOAD_CONST              12 ('%4d: %s')
#             366 LOAD_FAST                3 (i_n)
#             368 BINARY_MODULO
#             370 CALL_METHOD              1
#             372 POP_TOP
#             374 EXTENDED_ARG             1
#             376 JUMP_ABSOLUTE          356
#
# 185     >>  378 LOAD_CONST              16 ('\n')
#             380 LOAD_METHOD             16 (join)
#             382 LOAD_FAST                1 (lines)
#             384 CALL_METHOD              1
#             386 RETURN_VALUE
#
# Disassembly of _get_code_object:
# 131           0 LOAD_GLOBAL              0 (hasattr)
#               2 LOAD_FAST                0 (x)
#               4 LOAD_CONST               1 ('__func__')
#               6 CALL_FUNCTION            2
#               8 POP_JUMP_IF_FALSE       16
#
# 132          10 LOAD_FAST                0 (x)
#              12 LOAD_ATTR                1 (__func__)
#              14 STORE_FAST               0 (x)
#
# 134     >>   16 LOAD_GLOBAL              0 (hasattr)
#              18 LOAD_FAST                0 (x)
#              20 LOAD_CONST               2 ('__code__')
#              22 CALL_FUNCTION            2
#              24 POP_JUMP_IF_FALSE       34
#
# 135          26 LOAD_FAST                0 (x)
#              28 LOAD_ATTR                2 (__code__)
#              30 STORE_FAST               0 (x)
#              32 JUMP_FORWARD            52 (to 86)
#
# 136     >>   34 LOAD_GLOBAL              0 (hasattr)
#              36 LOAD_FAST                0 (x)
#              38 LOAD_CONST               3 ('gi_code')
#              40 CALL_FUNCTION            2
#              42 POP_JUMP_IF_FALSE       52
#
# 137          44 LOAD_FAST                0 (x)
#              46 LOAD_ATTR                3 (gi_code)
#              48 STORE_FAST               0 (x)
#              50 JUMP_FORWARD            34 (to 86)
#
# 138     >>   52 LOAD_GLOBAL              0 (hasattr)
#              54 LOAD_FAST                0 (x)
#              56 LOAD_CONST               4 ('ag_code')
#              58 CALL_FUNCTION            2
#              60 POP_JUMP_IF_FALSE       70
#
# 139          62 LOAD_FAST                0 (x)
#              64 LOAD_ATTR                4 (ag_code)
#              66 STORE_FAST               0 (x)
#              68 JUMP_FORWARD            16 (to 86)
#
# 140     >>   70 LOAD_GLOBAL              0 (hasattr)
#              72 LOAD_FAST                0 (x)
#              74 LOAD_CONST               5 ('cr_code')
#              76 CALL_FUNCTION            2
#              78 POP_JUMP_IF_FALSE       86
#
# 141          80 LOAD_FAST                0 (x)
#              82 LOAD_ATTR                5 (cr_code)
#              84 STORE_FAST               0 (x)
#
# 143     >>   86 LOAD_GLOBAL              6 (isinstance)
#              88 LOAD_FAST                0 (x)
#              90 LOAD_GLOBAL              7 (str)
#              92 CALL_FUNCTION            2
#              94 POP_JUMP_IF_FALSE      106
#
# 144          96 LOAD_GLOBAL              8 (_try_compile)
#              98 LOAD_FAST                0 (x)
#             100 LOAD_CONST               6 ('<disassembly>')
#             102 CALL_FUNCTION            2
#             104 STORE_FAST               0 (x)
#
# 146     >>  106 LOAD_GLOBAL              0 (hasattr)
#             108 LOAD_FAST                0 (x)
#             110 LOAD_CONST               7 ('co_code')
#             112 CALL_FUNCTION            2
#             114 POP_JUMP_IF_FALSE      120
#
# 147         116 LOAD_FAST                0 (x)
#             118 RETURN_VALUE
#
# 148     >>  120 LOAD_GLOBAL              9 (TypeError)
#             122 LOAD_CONST               8 ("don't know how to disassemble %s objects")
#
# 149         124 LOAD_GLOBAL             10 (type)
#             126 LOAD_FAST                0 (x)
#             128 CALL_FUNCTION            1
#             130 LOAD_ATTR               11 (__name__)
#
# 148         132 BINARY_MODULO
#             134 CALL_FUNCTION            1
#             136 RAISE_VARARGS            1
#             138 LOAD_CONST               9 (None)
#             140 RETURN_VALUE
#
# Disassembly of _get_const_info:
# 290           0 LOAD_FAST                0 (const_index)
#               2 STORE_FAST               2 (argval)
#
# 291           4 LOAD_FAST                1 (const_list)
#               6 LOAD_CONST               1 (None)
#               8 IS_OP                    1
#              10 POP_JUMP_IF_FALSE       20
#
# 292          12 LOAD_FAST                1 (const_list)
#              14 LOAD_FAST                0 (const_index)
#              16 BINARY_SUBSCR
#              18 STORE_FAST               2 (argval)
#
# 293     >>   20 LOAD_FAST                2 (argval)
#              22 LOAD_GLOBAL              0 (repr)
#              24 LOAD_FAST                2 (argval)
#              26 CALL_FUNCTION            1
#              28 BUILD_TUPLE              2
#              30 RETURN_VALUE
#
# Disassembly of _get_instructions_bytes:
# 321           0 LOAD_GLOBAL              0 (findlabels)
#               2 LOAD_FAST                0 (code)
#               4 CALL_FUNCTION            1
#               6 STORE_FAST               7 (labels)
#
# 322           8 LOAD_CONST               1 (None)
#              10 STORE_FAST               8 (starts_line)
#
# 323          12 LOAD_GLOBAL              1 (_unpack_opargs)
#              14 LOAD_FAST                0 (code)
#              16 CALL_FUNCTION            1
#              18 GET_ITER
#         >>   20 EXTENDED_ARG             1
#              22 FOR_ITER               370 (to 394)
#              24 UNPACK_SEQUENCE          3
#              26 STORE_FAST               9 (offset)
#              28 STORE_FAST              10 (op)
#              30 STORE_DEREF              0 (arg)
#
# 324          32 LOAD_FAST                5 (linestarts)
#              34 LOAD_CONST               1 (None)
#              36 IS_OP                    1
#              38 POP_JUMP_IF_FALSE       68
#
# 325          40 LOAD_FAST                5 (linestarts)
#              42 LOAD_METHOD              2 (get)
#              44 LOAD_FAST                9 (offset)
#              46 LOAD_CONST               1 (None)
#              48 CALL_METHOD              2
#              50 STORE_FAST               8 (starts_line)
#
# 326          52 LOAD_FAST                8 (starts_line)
#              54 LOAD_CONST               1 (None)
#              56 IS_OP                    1
#              58 POP_JUMP_IF_FALSE       68
#
# 327          60 LOAD_FAST                8 (starts_line)
#              62 LOAD_FAST                6 (line_offset)
#              64 INPLACE_ADD
#              66 STORE_FAST               8 (starts_line)
#
# 328     >>   68 LOAD_FAST                9 (offset)
#              70 LOAD_FAST                7 (labels)
#              72 CONTAINS_OP              0
#              74 STORE_FAST              11 (is_jump_target)
#
# 329          76 LOAD_CONST               1 (None)
#              78 STORE_FAST              12 (argval)
#
# 330          80 LOAD_CONST               2 ('')
#              82 STORE_FAST              13 (argrepr)
#
# 331          84 LOAD_DEREF               0 (arg)
#              86 LOAD_CONST               1 (None)
#              88 IS_OP                    1
#              90 EXTENDED_ARG             1
#              92 POP_JUMP_IF_FALSE      364
#
# 336          94 LOAD_DEREF               0 (arg)
#              96 STORE_FAST              12 (argval)
#
# 337          98 LOAD_FAST               10 (op)
#             100 LOAD_GLOBAL              3 (hasconst)
#             102 CONTAINS_OP              0
#             104 POP_JUMP_IF_FALSE      122
#
# 338         106 LOAD_GLOBAL              4 (_get_const_info)
#             108 LOAD_DEREF               0 (arg)
#             110 LOAD_FAST                3 (constants)
#             112 CALL_FUNCTION            2
#             114 UNPACK_SEQUENCE          2
#             116 STORE_FAST              12 (argval)
#             118 STORE_FAST              13 (argrepr)
#             120 JUMP_FORWARD           242 (to 364)
#
# 339     >>  122 LOAD_FAST               10 (op)
#             124 LOAD_GLOBAL              5 (hasname)
#             126 CONTAINS_OP              0
#             128 POP_JUMP_IF_FALSE      146
#
# 340         130 LOAD_GLOBAL              6 (_get_name_info)
#             132 LOAD_DEREF               0 (arg)
#             134 LOAD_FAST                2 (names)
#             136 CALL_FUNCTION            2
#             138 UNPACK_SEQUENCE          2
#             140 STORE_FAST              12 (argval)
#             142 STORE_FAST              13 (argrepr)
#             144 JUMP_FORWARD           218 (to 364)
#
# 341     >>  146 LOAD_FAST               10 (op)
#             148 LOAD_GLOBAL              7 (hasjrel)
#             150 CONTAINS_OP              0
#             152 POP_JUMP_IF_FALSE      180
#
# 342         154 LOAD_FAST                9 (offset)
#             156 LOAD_CONST               3 (2)
#             158 BINARY_ADD
#             160 LOAD_DEREF               0 (arg)
#             162 BINARY_ADD
#             164 STORE_FAST              12 (argval)
#
# 343         166 LOAD_CONST               4 ('to ')
#             168 LOAD_GLOBAL              8 (repr)
#             170 LOAD_FAST               12 (argval)
#             172 CALL_FUNCTION            1
#             174 BINARY_ADD
#             176 STORE_FAST              13 (argrepr)
#             178 JUMP_FORWARD           184 (to 364)
#
# 344     >>  180 LOAD_FAST               10 (op)
#             182 LOAD_GLOBAL              9 (haslocal)
#             184 CONTAINS_OP              0
#             186 POP_JUMP_IF_FALSE      204
#
# 345         188 LOAD_GLOBAL              6 (_get_name_info)
#             190 LOAD_DEREF               0 (arg)
#             192 LOAD_FAST                1 (varnames)
#             194 CALL_FUNCTION            2
#             196 UNPACK_SEQUENCE          2
#             198 STORE_FAST              12 (argval)
#             200 STORE_FAST              13 (argrepr)
#             202 JUMP_FORWARD           160 (to 364)
#
# 346     >>  204 LOAD_FAST               10 (op)
#             206 LOAD_GLOBAL             10 (hascompare)
#             208 CONTAINS_OP              0
#             210 POP_JUMP_IF_FALSE      226
#
# 347         212 LOAD_GLOBAL             11 (cmp_op)
#             214 LOAD_DEREF               0 (arg)
#             216 BINARY_SUBSCR
#             218 STORE_FAST              12 (argval)
#
# 348         220 LOAD_FAST               12 (argval)
#             222 STORE_FAST              13 (argrepr)
#             224 JUMP_FORWARD           138 (to 364)
#
# 349     >>  226 LOAD_FAST               10 (op)
#             228 LOAD_GLOBAL             12 (hasfree)
#             230 CONTAINS_OP              0
#             232 POP_JUMP_IF_FALSE      250
#
# 350         234 LOAD_GLOBAL              6 (_get_name_info)
#             236 LOAD_DEREF               0 (arg)
#             238 LOAD_FAST                4 (cells)
#             240 CALL_FUNCTION            2
#             242 UNPACK_SEQUENCE          2
#             244 STORE_FAST              12 (argval)
#             246 STORE_FAST              13 (argrepr)
#             248 JUMP_FORWARD           114 (to 364)
#
# 351     >>  250 LOAD_FAST               10 (op)
#             252 LOAD_GLOBAL             13 (FORMAT_VALUE)
#             254 COMPARE_OP               2 (==)
#             256 EXTENDED_ARG             1
#             258 POP_JUMP_IF_FALSE      326
#
# 352         260 LOAD_GLOBAL             14 (FORMAT_VALUE_CONVERTERS)
#             262 LOAD_DEREF               0 (arg)
#             264 LOAD_CONST               5 (3)
#             266 BINARY_AND
#             268 BINARY_SUBSCR
#             270 UNPACK_SEQUENCE          2
#             272 STORE_FAST              12 (argval)
#             274 STORE_FAST              13 (argrepr)
#
# 353         276 LOAD_FAST               12 (argval)
#             278 LOAD_GLOBAL             15 (bool)
#             280 LOAD_DEREF               0 (arg)
#             282 LOAD_CONST               6 (4)
#             284 BINARY_AND
#             286 CALL_FUNCTION            1
#             288 BUILD_TUPLE              2
#             290 STORE_FAST              12 (argval)
#
# 354         292 LOAD_FAST               12 (argval)
#             294 LOAD_CONST               7 (1)
#             296 BINARY_SUBSCR
#             298 EXTENDED_ARG             1
#             300 POP_JUMP_IF_FALSE      364
#
# 355         302 LOAD_FAST               13 (argrepr)
#             304 EXTENDED_ARG             1
#             306 POP_JUMP_IF_FALSE      316
#
# 356         308 LOAD_FAST               13 (argrepr)
#             310 LOAD_CONST               8 (', ')
#             312 INPLACE_ADD
#             314 STORE_FAST              13 (argrepr)
#
# 357     >>  316 LOAD_FAST               13 (argrepr)
#             318 LOAD_CONST               9 ('with format')
#             320 INPLACE_ADD
#             322 STORE_FAST              13 (argrepr)
#             324 JUMP_FORWARD            38 (to 364)
#
# 358     >>  326 LOAD_FAST               10 (op)
#             328 LOAD_GLOBAL             16 (MAKE_FUNCTION)
#             330 COMPARE_OP               2 (==)
#             332 EXTENDED_ARG             1
#             334 POP_JUMP_IF_FALSE      364
#
# 359         336 LOAD_CONST               8 (', ')
#             338 LOAD_METHOD             17 (join)
#             340 LOAD_CLOSURE             0 (arg)
#             342 BUILD_TUPLE              1
#             344 LOAD_CONST              10 (<code object <genexpr> at 0x7fcdd5ab9a80, file "/opt/anaconda3/envs/trainingAI/lib/python3.9/dis.py", line 359>)
#             346 LOAD_CONST              11 ('_get_instructions_bytes.<locals>.<genexpr>')
#             348 MAKE_FUNCTION            8 (closure)
#             350 LOAD_GLOBAL             18 (enumerate)
#             352 LOAD_GLOBAL             19 (MAKE_FUNCTION_FLAGS)
#             354 CALL_FUNCTION            1
#             356 GET_ITER
#             358 CALL_FUNCTION            1
#             360 CALL_METHOD              1
#             362 STORE_FAST              13 (argrepr)
#
# 361     >>  364 LOAD_GLOBAL             20 (Instruction)
# ...
# 367           0 LOAD_FAST                0 (co)
#               2 LOAD_ATTR                0 (co_cellvars)
#               4 LOAD_FAST                0 (co)
#               6 LOAD_ATTR                1 (co_freevars)
#               8 BINARY_ADD
#              10 STORE_FAST               3 (cell_names)
#
# 368          12 LOAD_GLOBAL              2 (dict)
#              14 LOAD_GLOBAL              3 (findlinestarts)
#              16 LOAD_FAST                0 (co)
#              18 CALL_FUNCTION            1
#              20 CALL_FUNCTION            1
#              22 STORE_FAST               4 (linestarts)
#
# 369          24 LOAD_GLOBAL              4 (_disassemble_bytes)
#              26 LOAD_FAST                0 (co)
#              28 LOAD_ATTR                5 (co_code)
#              30 LOAD_FAST                1 (lasti)
#              32 LOAD_FAST                0 (co)
#              34 LOAD_ATTR                6 (co_varnames)
#              36 LOAD_FAST                0 (co)
#              38 LOAD_ATTR                7 (co_names)
#
# 370          40 LOAD_FAST                0 (co)
#              42 LOAD_ATTR                8 (co_consts)
#              44 LOAD_FAST                3 (cell_names)
#              46 LOAD_FAST                4 (linestarts)
#              48 LOAD_FAST                2 (file)
#
# 369          50 LOAD_CONST               1 (('file',))
#              52 CALL_FUNCTION_KW         8
#              54 POP_TOP
#              56 LOAD_CONST               2 (None)
#              58 RETURN_VALUE
#
# Disassembly of disco:
# 367           0 LOAD_FAST                0 (co)
#               2 LOAD_ATTR                0 (co_cellvars)
#               4 LOAD_FAST                0 (co)
#               6 LOAD_ATTR                1 (co_freevars)
#               8 BINARY_ADD
#              10 STORE_FAST               3 (cell_names)
#
# 368          12 LOAD_GLOBAL              2 (dict)
#              14 LOAD_GLOBAL              3 (findlinestarts)
#              16 LOAD_FAST                0 (co)
#              18 CALL_FUNCTION            1
#              20 CALL_FUNCTION            1
#              22 STORE_FAST               4 (linestarts)
#
# 369          24 LOAD_GLOBAL              4 (_disassemble_bytes)
#              26 LOAD_FAST                0 (co)
#              28 LOAD_ATTR                5 (co_code)
#              30 LOAD_FAST                1 (lasti)
#              32 LOAD_FAST                0 (co)
#              34 LOAD_ATTR                6 (co_varnames)
#              36 LOAD_FAST                0 (co)
#              38 LOAD_ATTR                7 (co_names)
# 370          40 LOAD_FAST                0 (co)
#              42 LOAD_ATTR                8 (co_consts)
#              44 LOAD_FAST                3 (cell_names)
#              46 LOAD_FAST                4 (linestarts)
#              48 LOAD_FAST                2 (file)
#
# 369          50 LOAD_CONST               1 (('file',))
#              52 CALL_FUNCTION_KW         8
#              54 POP_TOP
#              56 LOAD_CONST               2 (None)
#              58 RETURN_VALUE
#
# Disassembly of distb:
#  90           0 LOAD_FAST                0 (tb)
#               2 LOAD_CONST               1 (None)
#               4 IS_OP                    0
#               6 POP_JUMP_IF_FALSE       62
#
#  91           8 SETUP_FINALLY           10 (to 20)
#
#  92          10 LOAD_GLOBAL              0 (sys)
#              12 LOAD_ATTR                1 (last_traceback)
#              14 STORE_FAST               0 (tb)
#              16 POP_BLOCK
#              18 JUMP_FORWARD            28 (to 48)
#
#  93     >>   20 DUP_TOP
#              22 LOAD_GLOBAL              2 (AttributeError)
#              24 JUMP_IF_NOT_EXC_MATCH    46
#              26 POP_TOP
#              28 POP_TOP
#              30 POP_TOP
#
#  94          32 LOAD_GLOBAL              3 (RuntimeError)
#              34 LOAD_CONST               2 ('no last traceback to disassemble')
#              36 CALL_FUNCTION            1
#              38 LOAD_CONST               1 (None)
#              40 RAISE_VARARGS            2
#              42 POP_EXCEPT
#              44 JUMP_FORWARD             2 (to 48)
#         >>   46 RERAISE
#
#  95     >>   48 LOAD_FAST                0 (tb)
#              50 LOAD_ATTR                4 (tb_next)
#              52 POP_JUMP_IF_FALSE       62
#              54 LOAD_FAST                0 (tb)
#              56 LOAD_ATTR                4 (tb_next)
#              58 STORE_FAST               0 (tb)
#              60 JUMP_ABSOLUTE           48
#
#  96     >>   62 LOAD_GLOBAL              5 (disassemble)
#              64 LOAD_FAST                0 (tb)
#              66 LOAD_ATTR                6 (tb_frame)
#              68 LOAD_ATTR                7 (f_code)
#              70 LOAD_FAST                0 (tb)
#              72 LOAD_ATTR                8 (tb_lasti)
#              74 LOAD_FAST                1 (file)
#              76 LOAD_CONST               3 (('file',))
#              78 CALL_FUNCTION_KW         3
#              80 POP_TOP
#              82 LOAD_CONST               1 (None)
#              84 RETURN_VALUE
#
# Disassembly of findlabels:
# 436           0 BUILD_LIST               0
#               2 STORE_FAST               1 (labels)
#
# 437           4 LOAD_GLOBAL              0 (_unpack_opargs)
#               6 LOAD_FAST                0 (code)
#               8 CALL_FUNCTION            1
#              10 GET_ITER
#         >>   12 FOR_ITER                74 (to 88)
#              14 UNPACK_SEQUENCE          3
#              16 STORE_FAST               2 (offset)
#              18 STORE_FAST               3 (op)
#              20 STORE_FAST               4 (arg)
#
# 438          22 LOAD_FAST                4 (arg)
#              24 LOAD_CONST               1 (None)
#              26 IS_OP                    1
#              28 POP_JUMP_IF_FALSE       12
#
# 439          30 LOAD_FAST                3 (op)
#              32 LOAD_GLOBAL              1 (hasjrel)
#              34 CONTAINS_OP              0
#              36 POP_JUMP_IF_FALSE       52
#
# 440          38 LOAD_FAST                2 (offset)
#              40 LOAD_CONST               2 (2)
#              42 BINARY_ADD
#              44 LOAD_FAST                4 (arg)
#              46 BINARY_ADD
#              48 STORE_FAST               5 (label)
#              50 JUMP_FORWARD            16 (to 68)
#
# 441     >>   52 LOAD_FAST                3 (op)
#              54 LOAD_GLOBAL              2 (hasjabs)
#              56 CONTAINS_OP              0
#              58 POP_JUMP_IF_FALSE       12
#
# 442          60 LOAD_FAST                4 (arg)
#              62 STORE_FAST               5 (label)
#              64 JUMP_FORWARD             2 (to 68)
#
# 444          66 JUMP_ABSOLUTE           12
#
# 445     >>   68 LOAD_FAST                5 (label)
#              70 LOAD_FAST                1 (labels)
#              72 CONTAINS_OP              1
#              74 POP_JUMP_IF_FALSE       12
#
# 446          76 LOAD_FAST                1 (labels)
#              78 LOAD_METHOD              3 (append)
#              80 LOAD_FAST                5 (label)
#              82 CALL_METHOD              1
#              84 POP_TOP
#              86 JUMP_ABSOLUTE           12
#
# 447     >>   88 LOAD_FAST                1 (labels)
#              90 RETURN_VALUE
#
# Disassembly of findlinestarts:
# 455           0 LOAD_FAST                0 (code)
#               2 LOAD_ATTR                0 (co_lnotab)
#               4 LOAD_CONST               1 (0)
#               6 LOAD_CONST               2 (None)
#               8 LOAD_CONST               3 (2)
#              10 BUILD_SLICE              3
#              12 BINARY_SUBSCR
#              14 STORE_FAST               1 (byte_increments)
#
# 456          16 LOAD_FAST                0 (code)
#              18 LOAD_ATTR                0 (co_lnotab)
#              20 LOAD_CONST               4 (1)
#              22 LOAD_CONST               2 (None)
#              24 LOAD_CONST               3 (2)
#              26 BUILD_SLICE              3
#              28 BINARY_SUBSCR
#              30 STORE_FAST               2 (line_increments)
#
# 457          32 LOAD_GLOBAL              1 (len)
#              34 LOAD_FAST                0 (code)
#              36 LOAD_ATTR                2 (co_code)
#              38 CALL_FUNCTION            1
#              40 STORE_FAST               3 (bytecode_len)
#
# 459          42 LOAD_CONST               2 (None)
#              44 STORE_FAST               4 (lastlineno)
#
# 460          46 LOAD_FAST                0 (code)
#              48 LOAD_ATTR                3 (co_firstlineno)
#              50 STORE_FAST               5 (lineno)
#
# 461          52 LOAD_CONST               1 (0)
#              54 STORE_FAST               6 (addr)
#
# 462          56 LOAD_GLOBAL              4 (zip)
#              58 LOAD_FAST                1 (byte_increments)
#              60 LOAD_FAST                2 (line_increments)
#              62 CALL_FUNCTION            2
#              64 GET_ITER
#         >>   66 FOR_ITER                80 (to 148)
#              68 UNPACK_SEQUENCE          2
#              70 STORE_FAST               7 (byte_incr)
#              72 STORE_FAST               8 (line_incr)
#
# 463          74 LOAD_FAST                7 (byte_incr)
#              76 POP_JUMP_IF_FALSE      122
#
# 464          78 LOAD_FAST                5 (lineno)
#              80 LOAD_FAST                4 (lastlineno)
#              82 COMPARE_OP               3 (!=)
#              84 POP_JUMP_IF_FALSE      100
#
# 465          86 LOAD_FAST                6 (addr)
#              88 LOAD_FAST                5 (lineno)
#              90 BUILD_TUPLE              2
#              92 YIELD_VALUE
#              94 POP_TOP
#
# 466          96 LOAD_FAST                5 (lineno)
#              98 STORE_FAST               4 (lastlineno)
#
# 467     >>  100 LOAD_FAST                6 (addr)
#             102 LOAD_FAST                7 (byte_incr)
#             104 INPLACE_ADD
#             106 STORE_FAST               6 (addr)
#
# 468         108 LOAD_FAST                6 (addr)
#             110 LOAD_FAST                3 (bytecode_len)
#             112 COMPARE_OP               5 (>=)
#             114 POP_JUMP_IF_FALSE      122
#
# 471         116 POP_TOP
#             118 LOAD_CONST               2 (None)
#             120 RETURN_VALUE
#
# 472     >>  122 LOAD_FAST                8 (line_incr)
#             124 LOAD_CONST               5 (128)
#             126 COMPARE_OP               5 (>=)
#             128 POP_JUMP_IF_FALSE      138
#
# 474         130 LOAD_FAST                8 (line_incr)
#             132 LOAD_CONST               6 (256)
#             134 INPLACE_SUBTRACT
#             136 STORE_FAST               8 (line_incr)
#
# 475     >>  138 LOAD_FAST                5 (lineno)
#             140 LOAD_FAST                8 (line_incr)
#             142 INPLACE_ADD
#             144 STORE_FAST               5 (lineno)
#             146 JUMP_ABSOLUTE           66
#
# 476     >>  148 LOAD_FAST                5 (lineno)
#             150 LOAD_FAST                4 (lastlineno)
#             152 COMPARE_OP               3 (!=)
#             154 POP_JUMP_IF_FALSE      166
#
# 477         156 LOAD_FAST                6 (addr)
#             158 LOAD_FAST                5 (lineno)
#             160 BUILD_TUPLE              2
#             162 YIELD_VALUE
#             164 POP_TOP
#         >>  166 LOAD_CONST               2 (None)
#             168 RETURN_VALUE
#
# Disassembly of get_instructions:
# 272           0 LOAD_GLOBAL              0 (_get_code_object)
#               2 LOAD_FAST                0 (x)
#               4 CALL_FUNCTION            1
#               6 STORE_FAST               2 (co)
#
# 273           8 LOAD_FAST                2 (co)
#              10 LOAD_ATTR                1 (co_cellvars)
#              12 LOAD_FAST                2 (co)
#              14 LOAD_ATTR                2 (co_freevars)
#              16 BINARY_ADD
#              18 STORE_FAST               3 (cell_names)
#
# 274          20 LOAD_GLOBAL              3 (dict)
#              22 LOAD_GLOBAL              4 (findlinestarts)
#              24 LOAD_FAST                2 (co)
#              26 CALL_FUNCTION            1
#              28 CALL_FUNCTION            1
#              30 STORE_FAST               4 (linestarts)
#
# 275          32 LOAD_FAST                1 (first_line)
#              34 LOAD_CONST               1 (None)
#              36 IS_OP                    1
#              38 POP_JUMP_IF_FALSE       52
#
# 276          40 LOAD_FAST                1 (first_line)
#              42 LOAD_FAST                2 (co)
#              44 LOAD_ATTR                5 (co_firstlineno)
#              46 BINARY_SUBTRACT
#              48 STORE_FAST               5 (line_offset)
#              50 JUMP_FORWARD             4 (to 56)
#
# 278     >>   52 LOAD_CONST               2 (0)
#              54 STORE_FAST               5 (line_offset)
#
# 279     >>   56 LOAD_GLOBAL              6 (_get_instructions_bytes)
#              58 LOAD_FAST                2 (co)
#              60 LOAD_ATTR                7 (co_code)
#              62 LOAD_FAST                2 (co)
#              64 LOAD_ATTR                8 (co_varnames)
#              66 LOAD_FAST                2 (co)
#              68 LOAD_ATTR                9 (co_names)
#
# 280          70 LOAD_FAST                2 (co)
#              72 LOAD_ATTR               10 (co_consts)
#              74 LOAD_FAST                3 (cell_names)
#              76 LOAD_FAST                4 (linestarts)
#
# 281          78 LOAD_FAST                5 (line_offset)
#
# 279          80 CALL_FUNCTION            7
#              82 RETURN_VALUE
#
# Disassembly of pretty_flags:
# 116           0 BUILD_LIST               0
#               2 STORE_FAST               1 (names)
#
# 117           4 LOAD_GLOBAL              0 (range)
#               6 LOAD_CONST               1 (32)
#               8 CALL_FUNCTION            1
#              10 GET_ITER
#         >>   12 FOR_ITER                58 (to 72)
#              14 STORE_FAST               2 (i)
#
# 118          16 LOAD_CONST               2 (1)
#              18 LOAD_FAST                2 (i)
#              20 BINARY_LSHIFT
#              22 STORE_FAST               3 (flag)
#
# 119          24 LOAD_FAST                0 (flags)
#              26 LOAD_FAST                3 (flag)
#              28 BINARY_AND
#              30 POP_JUMP_IF_FALSE       12
#
# 120          32 LOAD_FAST                1 (names)
#              34 LOAD_METHOD              1 (append)
#              36 LOAD_GLOBAL              2 (COMPILER_FLAG_NAMES)
#              38 LOAD_METHOD              3 (get)
#              40 LOAD_FAST                3 (flag)
#              42 LOAD_GLOBAL              4 (hex)
#              44 LOAD_FAST                3 (flag)
#              46 CALL_FUNCTION            1
#              48 CALL_METHOD              2
#              50 CALL_METHOD              1
#              52 POP_TOP
#
# 121          54 LOAD_FAST                0 (flags)
#              56 LOAD_FAST                3 (flag)
#              58 INPLACE_XOR
#              60 STORE_FAST               0 (flags)
#
# 122          62 LOAD_FAST                0 (flags)
#              64 POP_JUMP_IF_TRUE        12
#
# 123          66 POP_TOP
#              68 JUMP_ABSOLUTE           86
#              70 JUMP_ABSOLUTE           12
#
# 125     >>   72 LOAD_FAST                1 (names)
#              74 LOAD_METHOD              1 (append)
#              76 LOAD_GLOBAL              4 (hex)
#              78 LOAD_FAST                0 (flags)
#              80 CALL_FUNCTION            1
#              82 CALL_METHOD              1
#              84 POP_TOP
#
# 126     >>   86 LOAD_CONST               3 (', ')
#              88 LOAD_METHOD              5 (join)
#              90 LOAD_FAST                1 (names)
#              92 CALL_METHOD              1
#              94 RETURN_VALUE
#
# Disassembly of show_code:
# 192           0 LOAD_GLOBAL              0 (print)
#               2 LOAD_GLOBAL              1 (code_info)
#               4 LOAD_FAST                0 (co)
#               6 CALL_FUNCTION            1
#               8 LOAD_FAST                1 (file)
#              10 LOAD_CONST               1 (('file',))
#              12 CALL_FUNCTION_KW         2
#              14 POP_TOP
#              16 LOAD_CONST               2 (None)
#              18 RETURN_VALUE

# %% [markdown]
# ## Feeding a function

# %%
def bar():
    x = 5
    y = 7
    z = x + y
    return z

dis.dis(bar)
# Out:
#   2           0 LOAD_CONST               1 (5)
#               2 STORE_FAST               0 (x)
#
#   3           4 LOAD_CONST               2 (7)
#               6 STORE_FAST               1 (y)
#
#   4           8 LOAD_FAST                0 (x)
#              10 LOAD_FAST                1 (y)
#              12 BINARY_ADD
#              14 STORE_FAST               2 (z)
#
#   5          16 LOAD_FAST                2 (z)
#              18 RETURN_VALUE

# %% [markdown]
# ## Feeding a class

# %%
class Foo(object):
    def __init__(self):
        pass

    def foo(self, x):
        return x + 1

dis.dis(Foo)
# Out:
# Disassembly of __init__:
#   3           0 LOAD_CONST               0 (None)
#               2 RETURN_VALUE
#
# Disassembly of foo:
#   6           0 LOAD_FAST                1 (x)
#               2 LOAD_CONST               1 (1)
#               4 BINARY_ADD
#               6 RETURN_VALUE

# %% [markdown]
# # References
# <hr style = "border:2px solid black" ></hr>

# %% [markdown]
# <div class="alert alert-warning">
# <font color=black>
#
# - https://nbviewer.org/github/rasbt/python_reference/blob/master/tutorials/not_so_obvious_python_stuff.ipynb?create=1
# - http://www.goldsborough.me/python/low-level/2016/10/04/00-31-30-disassembling_python_bytecode/
#
# </font>
# </div>
